# %%
import numpy as np
import pandas as pd

# %%
print("creating a dataframe")
# Out:
# creating a dataframe

# %%
data={
    'Name':['john','Anna','Peter','Linda'],
    'Age':[28,34,29,42],
    'City':['New York','Paris','Berlin','London'],
    'Salary':[65000,70000,62000,85000]
}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list=[
    ['john',28,'New york',65000],
    ['Anna',34,'Paris',70000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',85000],
]
df2=pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   john  28  New york  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
print("selection and indexing of column")
# Out:
# selection and indexing of column

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
df2[['City','Name']]
# Out:
#        City   Name
# 0  New York   John
# 1     Paris   Anna
# 2    Berlin  Peter
# 3    London  Linda

# %%
print('creating a column')
# Out:
# creating a column

# %%
df2["designation"]=["doctor","enginner","actor","vlogger"]

# %%
df2
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000    enginner
# 2  Peter   29    Berlin   62000       actor
# 3  Linda   42    London   85000     vlogger

# %%
print("remove column")
# Out:
# remove column

# %%
df2.drop(["designation", "Salary"], axis=1)   #inplace true used for actualy deleting from dataframe
# Out:
#     Name  Age      City
# 0   John   28  New York
# 1   Anna   34     Paris
# 2  Peter   29    Berlin
# 3  Linda   42    London

# %%
df2
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000    enginner
# 2  Peter   29    Berlin   62000       actor
# 3  Linda   42    London   85000     vlogger

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary designation
# 1   Anna   34   Paris   70000    enginner
# 2  Peter   29  Berlin   62000       actor
# 3  Linda   42  London   85000     vlogger

# %%
print("selecting rows")
# Out:
# selecting rows

# %%
df2.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# designation      doctor
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary designation
# 0  John   28  New York   65000      doctor
# 1  Anna   34     Paris   70000    enginner

# %%
df2.iloc[3]  #index location baat wahi hai par index kuch bhi ho skta hai
# Out:
# Name             Linda
# Age                 42
# City            London
# Salary           85000
# designation    vlogger
# Name: 3, dtype: object

# %%
print("selecting subsets of rows and columns")
# Out:
# selecting subsets of rows and columns

# %%
df.loc[[0,1]][["Name","Age"]]
# Out:
#    Name  Age
# 0  john   28
# 1  Anna   34

# %%
df.loc[[2,1]][["City","Salary"]]
# Out:
#      City  Salary
# 2  Berlin   62000
# 1   Paris   70000

# %%
print("conditional selection")
# Out:
# conditional selection

# %%
#i only want to see whose age is greater than 30

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary designation
# 1   Anna   34   Paris   70000    enginner
# 3  Linda   42  London   85000     vlogger

# %%
#i only want to see whose age is greater than 30 and there city must be paris

# %%
df2[(df2["Age"]>30) & (df2["City"]=="Paris")]
# Out:
#    Name  Age   City  Salary designation
# 1  Anna   34  Paris   70000    enginner

# %%
# Out:
# missing data
